# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd

# Reload the dataset
file_path = "../sales_data.csv"
df = pd.read_csv(file_path)

# %%
# Display basic information and the first few rows
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   distributor_id        10000 non-null  object
#  1   industry              10000 non-null  object
#  2   sku                   10000 non-null  object
#  3   category              10000 non-null  object
#  4   sales                 10000 non-null  float64
#  5   avg_quarterly_sales   10000 non-null  float64
#  6   movement_category     10000 non-null  object
#  7   quarter               10000 non-null  int64
#  8   year                  10000 non-null  int64
#  9   total_quarter_sales   10000 non-null  float64
#  10  prev_quarter_sales    10000 non-null  float64
#  11  is_diwali             10000 non-null  int64
#  12  is_ganesh_chaturthi   10000 non-null  int64
#  13  is_gudi_padwa         10000 non-null  int64
#  14  is_eid                10000 non-null  int64
#  15  is_akshay_tritiya     10000 non-null  int64
#  16  is_dussehra_navratri  10000 non-null  int64
#  17  is_onam               10000 non-null  int64
#  18  is_christmas          10000 non-null  int64
#  19  time_idx              10000 non-null  int64
# dtypes: float64(4), int64(11), object(5)
# memory usage: 1.5+ MB

# %%
df.head()
# Out:
#   distributor_id       industry                            sku    category  \
# 0        DIST036     Healthcare               MDH Garam Masala        Food
# 1        DIST007     E-commerce           Shell Helix Ultra 4L  Automotive
# 2        DIST012         Retail  PlayStation 5 Digital Edition        Toys
# 3        DIST034     E-commerce  PlayStation 5 Digital Edition        Toys
# 4        DIST009  Manufacturing     Britannia Good Day Cookies        Food
#
#       sales  avg_quarterly_sales movement_category  quarter  year  \
# 0   4726.09              6345.93       Fast Moving        2  2022
# 1   4015.00              4141.90       Slow Moving        3  2023
# 2  12386.14             13593.10            Medium        2  2024
# 3  13198.10             13593.10            Medium        4  2020
# 4   3148.80              4600.58            Medium        1  2023
#
#    total_quarter_sales  prev_quarter_sales  is_diwali  is_ganesh_chaturthi  \
# 0              4726.09             9533.64          0                    0
# 1              4015.00             3504.12          0                    1
# 2             12386.14            11915.21          0                    0
# 3             13198.10             9534.84          1                    0
# 4              3148.80             5176.39          0                    0
#
#    is_gudi_padwa  is_eid  is_akshay_tritiya  is_dussehra_navratri  is_onam  \
# 0              1       0                  1                     0        0
# 1              0       1                  0                     1        1
# 2              1       1                  1                     0        0
# 3              0       1                  0                     1        0
# 4              1       1                  0                     0        0
#
#    is_christmas  time_idx
# 0             0     26645
# 1             0      4927
# 2             0      8683
# 3             1     25185
# 4             0      6160

# %%
# Check for missing values
missing_values = df.isnull().sum()

missing_values
# Out:
# distributor_id          0
# industry                0
# sku                     0
# category                0
# sales                   0
# avg_quarterly_sales     0
# movement_category       0
# quarter                 0
# year                    0
# total_quarter_sales     0
# prev_quarter_sales      0
# is_diwali               0
# is_ganesh_chaturthi     0
# is_gudi_padwa           0
# is_eid                  0
# is_akshay_tritiya       0
# is_dussehra_navratri    0
# is_onam                 0
# is_christmas            0
# time_idx                0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Set plot style
sns.set_style("whitegrid")

# %%
# Plot sales distribution
plt.figure(figsize=(10, 5))
sns.histplot(df["sales"], bins=50, kde=True, color="blue")
plt.title("Sales Distribution")
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.show()

# %%
# Time series sales trend by year and quarter
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x="time_idx", y="sales", hue="year", palette="coolwarm", alpha=0.7)
plt.title("Sales Trend Over Time")
plt.xlabel("Time Index")
plt.ylabel("Sales")
plt.legend(title="Year")
plt.show()
